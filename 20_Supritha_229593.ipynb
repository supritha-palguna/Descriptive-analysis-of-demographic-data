# %% [markdown]
# # Introductory to Case Studies - Project 1

# %% [markdown]
# ### Team members - Group 20
# 1. Dhanunjaya Elluri Thimmaraju
# 2. Kunal Kochar
# 3. Naveen Kumar Bhageradhi
# 4. Ashish Saini
# 5. Supritha Palguna
# 6. Harshini Eggoni

# %%
import sys
print("Python version")
print(sys.version)
# Out:
# Python version
# 3.9.7 | packaged by conda-forge | (default, Sep 29 2021, 20:33:18)
# [Clang 11.1.0 ]

# %%
# Install the following packages
# !conda install -c conda -y matplotlib
# !conda install -c conda -y pandas
# !conda install -c conda -y seaborn
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns 
import warnings

# %%
warnings.filterwarnings("ignore")

# %%
census_data = pd.read_csv('census_2022_2002.csv', encoding="ISO-8859-1")

# %%
census_data.head()
# Out:
#        country  region           subregion  year  total.fertility.rate  \
# 0  Afghanistan    Asia  South-Central Asia  2002                6.0000
# 1  Afghanistan    Asia  South-Central Asia  2022                4.6240
# 2      Albania  Europe     Southern Europe  2002                1.9949
# 3      Albania  Europe     Southern Europe  2022                1.5402
# 4      Algeria  Africa     Northern Africa  2002                2.3304
#
#    life.expectancy.both.sexes  life.expectancy.males  life.expectancy.females
# 0                       46.10                  45.11                    47.15
# 1                       53.65                  52.10                    55.28
# 2                       75.44                  72.79                    78.43
# 3                       79.47                  76.80                    82.33
# 4                       72.99                  72.06                    73.97

# %%
len(census_data.region.unique())
# Out:
# 5

# %%
census_data.shape
# Out:
# (454, 8)

# %%
# Null values
census_data.isna().sum()
# Out:
# country                       0
# region                        0
# subregion                     0
# year                          0
# total.fertility.rate          6
# life.expectancy.both.sexes    6
# life.expectancy.males         6
# life.expectancy.females       6
# dtype: int64

# %%
is_NaN = census_data.isnull()
row_has_NaN = is_NaN.any(axis=1)
rows_with_NaN = census_data[row_has_NaN]
rows_with_NaN
# Out:
#            country    region         subregion  year  total.fertility.rate  \
# 234          Libya    Africa   Northern Africa  2002                   NaN
# 324    Puerto Rico  Americas         Caribbean  2002                   NaN
# 378    South Sudan    Africa   Northern Africa  2002                   NaN
# 384          Sudan    Africa   Northern Africa  2002                   NaN
# 392          Syria      Asia      Western Asia  2002                   NaN
# 428  United States  Americas  Northern America  2002                   NaN
#
#      life.expectancy.both.sexes  life.expectancy.males  \
# 234                         NaN                    NaN
# 324                         NaN                    NaN
# 378                         NaN                    NaN
# 384                         NaN                    NaN
# 392                         NaN                    NaN
# 428                         NaN                    NaN
#
#      life.expectancy.females
# 234                      NaN
# 324                      NaN
# 378                      NaN
# 384                      NaN
# 392                      NaN
# 428                      NaN

# %%
census_data['region'].unique()
# Out:
# array(['Asia', 'Europe', 'Africa', 'Oceania', 'Americas'], dtype=object)

# %%
census_data['subregion'].unique().shape
# Out:
# (21,)

# %%
data_description = census_data[['total.fertility.rate', 'life.expectancy.both.sexes', 
             'life.expectancy.males', 'life.expectancy.females']].describe()
data_description
# Out:
#        total.fertility.rate  life.expectancy.both.sexes  \
# count            448.000000                  448.000000
# mean               2.701384                   71.758080
# std                1.444490                    8.728865
# min                0.837400                   44.580000
# 25%                1.687075                   67.877500
# 50%                2.107000                   73.765000
# 75%                3.445775                   78.032500
# max                8.200000                   89.520000
#
#        life.expectancy.males  life.expectancy.females
# count             448.000000               448.000000
# mean               69.362076                74.278080
# std                 8.429339                 9.162633
# min                43.540000                44.990000
# 25%                65.315000                69.910000
# 50%                71.275000                76.565000
# 75%                75.267500                80.982500
# max                85.700000                93.490000

# %%
data_description.to_csv('data_description.csv')

# %%
census_data.shape
# Out:
# (454, 8)

# %% [markdown]
# ### Task 1: Describe the frequency distributions of the variables. Consider also the differences between the sexes.

# %%
census_data_2022 = census_data[census_data['year'] == 2022]

# %%
census_data_2022.shape
# Out:
# (227, 8)

# %%
a = sns.histplot(data = census_data_2022, x = 'total.fertility.rate', stat='density',
             palette='tab10')
a.set_xlabel("Total fertility rate", fontsize = 10)
a.set_ylabel('Density', fontsize = 10)
plt.savefig('frequency_distribution1_a.eps', format='eps', bbox_inches='tight', dpi=200)
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
b = sns.histplot(data = census_data_2022, x = 'life.expectancy.both.sexes', stat='density',
             palette='tab10')

b.set(xlim=(50, 95))
b.set(ylim=(0, 0.08))
b.set_xlabel("Life expectancy both sexes", fontsize = 10)
b.set_ylabel('Density', fontsize = 10)
plt.savefig('frequency_distribution1_b.eps', format='eps', bbox_inches='tight', dpi=200)
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
c = sns.histplot(data = census_data_2022, x = 'life.expectancy.males', stat='density')
c.set(xlim=(50, 95))
c.set(ylim=(0, 0.08))
c.set_xlabel("Life expectancy males", fontsize = 10)
c.set_ylabel('Density', fontsize = 10)
plt.savefig('frequency_distribution1_c.eps', format='eps', bbox_inches='tight', dpi=200)
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
d = sns.histplot(data=census_data_2022, x='life.expectancy.females', stat='density')
d.set(xlim=(50, 95))
d.set(ylim=(0, 0.08))
d.set_xlabel("Life expectancy females", fontsize = 10)
d.set_ylabel('Density', fontsize = 10)

plt.savefig('frequency_distribution1_d.eps', format='eps', bbox_inches='tight', dpi=200)
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# #### Differences between sexes

# %%
fig = plt.figure(figsize=(8, 5), dpi = 80)

males = plt.scatter(data=census_data_2022, x="life.expectancy.both.sexes", y="life.expectancy.males", marker='+')
females = plt.scatter(data=census_data_2022, x="life.expectancy.both.sexes", y="life.expectancy.females", marker='.')

plt.xlabel('Life expectancy range',fontsize=14)
plt.ylabel('Life expectancy range',fontsize=14)
# plt.title('Differences between the sexes',fontsize=12, y=1.03)
plt.legend((females, males), ['Females','Males'], loc='upper left')
plt.savefig('different_between_sexes.jpg', dpi=110.0, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Task 2: Are there bivariate correlations between the variables?

# %%
census_data_2022_variables = census_data_2022.drop(columns = ['country', 'subregion', 'region', 'year'])

# %%
census_data_2022_variables.head()
# Out:
#    total.fertility.rate  life.expectancy.both.sexes  life.expectancy.males  \
# 1                4.6240                       53.65                  52.10
# 3                1.5402                       79.47                  76.80
# 5                2.5058                       78.03                  76.57
# 7                2.2060                       75.32                  72.83
# 9                1.4474                       83.42                  81.20
#
#    life.expectancy.females
# 1                    55.28
# 3                    82.33
# 5                    79.57
# 7                    77.97
# 9                    85.79

# %%
sns.pairplot(census_data_2022_variables)

# %%
correlation = census_data_2022_variables.corr()

# %%
correlation.to_csv('correlation.csv', index = False)

# %%
correlation
# Out:
#                             total.fertility.rate  life.expectancy.both.sexes  \
# total.fertility.rate                    1.000000                   -0.788528
# life.expectancy.both.sexes             -0.788528                    1.000000
# life.expectancy.males                  -0.760606                    0.992615
# life.expectancy.females                -0.805001                    0.992935
#
#                             life.expectancy.males  life.expectancy.females
# total.fertility.rate                    -0.760606                -0.805001
# life.expectancy.both.sexes               0.992615                 0.992935
# life.expectancy.males                    1.000000                 0.971249
# life.expectancy.females                  0.971249                 1.000000

# %%
fig, axes = plt.subplots(1, 3, figsize=(10, 4), dpi=90)
a = sns.scatterplot(data=census_data_2022_variables, x='life.expectancy.both.sexes', y='total.fertility.rate', ax=axes[0])
a.set_xlabel("Life expectancy both sexes", fontsize = 11)
a.set_ylabel('Total fertility rate', fontsize = 10)
a.set(xlim=(50, 95))

b = sns.scatterplot(data=census_data_2022_variables, x='life.expectancy.females', y='total.fertility.rate', ax=axes[1])
b.set_xlabel("Life expectancy females", fontsize = 11)
b.set_ylabel('Total fertility rate', fontsize = 10)
b.set(xlim=(50, 95))

c = sns.scatterplot(data=census_data_2022_variables, x='life.expectancy.males', y='total.fertility.rate', ax=axes[2])
c.set_xlabel("Life expectancy males", fontsize = 11)
c.set_ylabel('Total fertility rate', fontsize = 10)
c.set(xlim=(50, 95))

#fig.suptitle('Change in life expectancy over 20 years',fontsize=12, y=1)
plt.tight_layout()
plt.savefig('negative_correlation.eps', format='eps', bbox_inches='tight')
plt.show()

# %%
fig, axes = plt.subplots(1, 3, figsize=(10, 4), dpi=90)
a = sns.scatterplot(data=census_data_2022_variables, x='life.expectancy.both.sexes', y='life.expectancy.males', ax=axes[0])
a.set_xlabel("Life expectancy both sexes", fontsize = 11)
a.set_ylabel('Life expectancy males', fontsize = 10)

b = sns.scatterplot(data=census_data_2022_variables, x='life.expectancy.both.sexes', y='life.expectancy.females', ax=axes[1])
b.set_xlabel("Life expectancy both sexes", fontsize = 11)
b.set_ylabel('Life expectancy females', fontsize = 10)

c = sns.scatterplot(data=census_data_2022_variables, x='life.expectancy.males', y='life.expectancy.females', ax=axes[2])
c.set_xlabel("Life expectancy males'", fontsize = 11)
c.set_ylabel('Life expectancy females', fontsize = 10)

#fig.suptitle('Change in life expectancy over 20 years',fontsize=12, y=1)
plt.tight_layout()
plt.savefig('positive_correlation.eps', format='eps', bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Task 3: Comparison of variability within and among subregions

# %% [markdown]
# #### 1. Total Fertility Rate

# %%
fig = plt.figure(figsize=(8,8), dpi = 90, frameon=True)
ax = sns.boxplot(data = census_data_2022.sort_values(by="region"),
                x = 'total.fertility.rate',
                y = 'subregion',
                width = 0.5,
                dodge=False,
                hue = 'region',
                palette="hls",
                orient="h")
plt.xlabel('Total fertility rate',fontsize=12)
plt.ylabel('Sub regions',fontsize=12)
# plt.title('Comparison of total fertility rate variability between sub-regions',fontsize=14, y=1.01)
plt.savefig('variability_in_total_fertility.eps', format='eps', bbox_inches='tight')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# #### 2. Life expectancy both sexes

# %%
fig = plt.figure(figsize=(6, 6), dpi = 90, frameon=True)
ax = sns.boxplot(data = census_data_2022.sort_values(by="region"),
                x = 'life.expectancy.both.sexes',
                y = 'subregion',
                hue = 'region',
                width = 0.5,
                dodge=False,
                palette="hls")
plt.xlabel('Life expectancy of both sexes',fontsize=12)
plt.ylabel('Sub regions',fontsize=12)
# plt.title('Comparison of life expectancy of both sexes variability between sub-regions',fontsize=14, y=1.01)
plt.savefig('variability_in_both_sexes.eps', format='eps', bbox_inches='tight')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# #### 3. Life expectancy males

# %%
fig = plt.figure(figsize=(6, 6), dpi = 90, frameon=True)
ax = sns.boxplot(data = census_data_2022.sort_values(by="region"),
                x = 'life.expectancy.males',
                y = 'subregion',
                hue = 'region',
                width = 0.5,
                dodge = False,
                palette="hls")
plt.xlabel('Life expectancy of males',fontsize=12)
plt.ylabel('Sub regions',fontsize=12)
# plt.title('Comparison of life expectancy of males variability between sub-regions',fontsize=14, y=1.01)
plt.savefig('variability_in_males.eps', format='eps', bbox_inches='tight')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# #### 4. Life expectancy females

# %%
fig = plt.figure(figsize=(6, 6), dpi = 90, frameon=True)
ax = sns.boxplot(data = census_data_2022.sort_values(by="region"),
                x = 'life.expectancy.females',
                y = 'subregion',
                hue = 'region',
                width = 0.5,
                dodge = False,
                palette="hls")
plt.xlabel('Life expectancy of females',fontsize=12)
plt.ylabel('Sub regions',fontsize=12)
# plt.title('Comparison of life expectancy of females variability between sub-regions',fontsize=14, y=1.01)
plt.savefig('variability_in_females.eps', format='eps',bbox_inches='tight')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# ### Task 4: How have the values of the variables changed over the last 20 years, i.e. comparing 2001 with 2021?

# %%
census_data.head()
# Out:
#        country  region           subregion  year  total.fertility.rate  \
# 0  Afghanistan    Asia  South-Central Asia  2002                6.0000
# 1  Afghanistan    Asia  South-Central Asia  2022                4.6240
# 2      Albania  Europe     Southern Europe  2002                1.9949
# 3      Albania  Europe     Southern Europe  2022                1.5402
# 4      Algeria  Africa     Northern Africa  2002                2.3304
#
#    life.expectancy.both.sexes  life.expectancy.males  life.expectancy.females
# 0                       46.10                  45.11                    47.15
# 1                       53.65                  52.10                    55.28
# 2                       75.44                  72.79                    78.43
# 3                       79.47                  76.80                    82.33
# 4                       72.99                  72.06                    73.97

# %%
def change_width(ax, new_value) :
    for patch in ax.patches :
        current_width = patch.get_width()
        diff = current_width - new_value

        # we change the bar width
        patch.set_width(new_value)

        # we recenter the bar
        patch.set_x(patch.get_x() + diff * .5)

# %%
fig, ax = plt.subplots(figsize=(3, 4))

a = sns.barplot(data=census_data, x='year', y='total.fertility.rate', ax=ax)
a.set_xlabel('Year', fontsize=11)
a.set_ylabel('Total fertility rate', fontsize=11)

change_width(ax, .60)

plt.savefig('change_in_life_expectancy_barplot_1a.eps', format='eps', bbox_inches='tight')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(3, 4))

b = sns.barplot(data=census_data, x='year', y='life.expectancy.both.sexes', ax=ax)
b.set_xlabel('Year', fontsize=11)
b.set_ylabel('Life expectancy of both sexes', fontsize=11)

change_width(ax, .60)

plt.savefig('change_in_life_expectancy_barplot_1b.eps', format='eps', bbox_inches='tight',dpi=200)
plt.show()

# %%
fig, axes = plt.subplots(2, 2, figsize=(9, 6), dpi=90)

a = sns.barplot(ax=axes[0, 0], data=census_data, 
                x='region', y='total.fertility.rate',
                hue='year')
a.set_xlabel("Region", fontsize = 11)
a.set_ylabel('Total fertility rate', fontsize = 11)
a.set(ylim=(0, 10))

b = sns.barplot(ax=axes[0, 1], data=census_data, 
                x='region', y='life.expectancy.both.sexes',
                hue='year')
b.set_xlabel("Region", fontsize = 11)
b.set_ylabel('Life expectancy of both sexes', fontsize = 11)
b.set(ylim=(30, 100))

c = sns.barplot(ax=axes[1, 0], data=census_data, 
                x='region', y='life.expectancy.males',
                hue='year')
c.set_xlabel("Region", fontsize = 11)
c.set_ylabel('Life expectancy of males', fontsize = 11)
c.set(ylim=(30, 100))

d = sns.barplot(ax=axes[1, 1], data=census_data, 
                x='region', y='life.expectancy.females',
                hue='year')
d.set_xlabel("Region", fontsize = 11)
d.set_ylabel('Life expectancy of females', fontsize = 11)
d.set(ylim=(30, 100))

# fig.suptitle('Change in life expectancy over 20 years',fontsize=12, y=1)
plt.tight_layout()
plt.savefig('change_in_life_expectancy_barplot_2.eps', format='eps', bbox_inches='tight')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
